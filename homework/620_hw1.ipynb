# %% [markdown]
# ## Homework 1
# ### A Krackhardt Kite graph
# This code is mostly taken straight out of the documentation here.
# https://networkx.org/documentation/stable/tutorial.html
#
# Along with this new repo, we included a reconfigured python virtualenv to run this and future code. Setup instructions are in the repositoriy's README.md.

# %%
import networkx as nx
import matplotlib.pyplot as plt



# set up the graph
G = nx.Graph()

# Build Nodes
nodes = ["Andre", "Beverly", "Carol", "Diane", "Ed", "Fernando", "Garth", "Heather", "Ike", "Jane"]
G.add_nodes_from(nodes)

#Build Edges
edges = [   ("Andre", "Carol"), 
            ("Andre", "Diane"), 
            ("Andre", "Fernando"),

            ("Beverly", "Diane"), 
            ("Beverly", "Garth"), 
            ("Beverly", "Ed"),

            ("Carol", "Fernando"), 
            ("Carol", "Diane"),

            ("Diane", "Fernando"), 
            ("Diane", "Garth"), 
            ("Diane", "Ed"), 

            ("Ed", "Garth"), 

            ("Fernando", "Heather"),
            ("Garth", "Heather"),
             
            ("Heather", "Ike"), 

            ("Ike", "Jane")]

G.add_edges_from(edges)

# build the layout
pos = nx.spring_layout(G)
nx.draw(G, pos, 
        with_labels=True, node_color="green", 
        node_size=2000, edge_color="purple", 
        font_size=15, font_color="black", 
        font_weight="bold")

plt.title("Krackhardt Kite Graph")

plt.show()
